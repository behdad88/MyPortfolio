# %%
import numpy as np
import pandas as pd
import os
import glob

# %% [markdown]
# # Reading csv files and concat them to one single pandas data frame

# %%
path = r'/Users/behdad/Learning/TwitterBot/Tweepy_Twitter_Scraper/' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename , encoding='utf-8')
    li.append(df)

dataframe = pd.concat(li, axis=0, ignore_index=True)

# %%
dataframe.shape
# Out:
# (21047, 15)

# %%
dataframe.head()
# Out:
#    Unnamed: 0             Datetime             Tweet Id  \
# 0           0  2020-02-06 09:29:10  1225350710935638016
# 1           1  2020-02-05 09:37:26  1224990403780280320
# 2           2  2020-02-05 09:27:28  1224987896668721152
# 3           3  2020-02-05 09:08:08  1224983029799694339
# 4           4  2020-02-05 09:06:08  1224982527112351745
#
#                                                 Text  retweet_count  \
# 0                              @samousavia میلی‌لیتر              0
# 1  RT @Majid6359: #سناتور_مکنزی وزیر کشاورزی و وز...              3
# 2  @omidhosseini80 ما گول نمی‌خوریم. یه عمریه هر ...              0
# 3  @omidhosseini80 یه آخوند بی‌عمامه دیدم. داشتم ...              0
# 4        @omidhosseini80 آخوند چرا نداره! یعنی میرن؟              0
#
#    favorite_count                                           entities  \
# 0               2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1               0  {'hashtags': [{'text': 'سناتور_مکنزی', 'indice...
# ...

# %%
dataframe.tail()
# Out:
#        Unnamed: 0             Datetime             Tweet Id  \
# 21042         195  2018-11-06 09:52:41  1059745377551872000
# 21043         196  2018-11-03 14:13:58  1058723965068283905
# 21044         197  2018-10-25 16:50:10  1055501786277134337
# 21045         198  2018-10-21 10:24:03  1053955064727953408
# 21046         199  2018-10-19 14:35:25  1053293548731158528
#
#                                                     Text  retweet_count  \
# 21042  مرثیه ی پیام رسان های داخلی،حاکی از ضعف مفرط ت...             42
# 21043  اعتقاد برخی سیاستمداران به ضرورت مذاکره با آمر...             27
# 21044  همه می‌دانستند که نقد کردن صد هزار دینار ناقاب...            300
# 21045  ضرغامی در گفتگو با ایرنا، درباره علت هشدار اخی...             21
# 21046  نمی‌خواهیم مردم را به زور به بهشت ببریم.\n ولی...            107
#
#        favorite_count                                           entities  \
# 21042             736  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
dataframe.to_csv('political_tweets.csv', header=True,encoding='utf-8')

# %%
dataframe.dtypes
# Out:
# Unnamed: 0                      int64
# Datetime               datetime64[ns]
# Tweet Id                        int64
# Text                           object
# retweet_count                   int64
# favorite_count                  int64
# entities                       object
# tweet_source                   object
# user_screenname                object
# user_name                      object
# location                       object
# user_description               object
# user_followers                  int64
# user_friends                    int64
# user_create_account    datetime64[ns]
# tweet_date             datetime64[ns]
# tweet_time                     object
# dtype: object

# %%
dataframe.columns
# Out:
# Index(['Unnamed: 0', 'Datetime', 'Tweet Id', 'Text', 'retweet_count',
#        'favorite_count', 'entities', 'tweet_source', 'user_screenname',
#        'user_name', 'location', 'user_description', 'user_followers',
#        'user_friends', 'user_create_account'],
#       dtype='object')

# %%
dataframe['Datetime'] = pd.to_datetime(dataframe['Datetime'])

dataframe['tweet_date'] = [d.date() for d in dataframe['Datetime']]
dataframe['tweet_time'] = [d.time() for d in dataframe['Datetime']]

# %%
dataframe.dtypes
# Out:
# Unnamed: 0                      int64
# Datetime               datetime64[ns]
# Tweet Id                        int64
# Text                           object
# retweet_count                   int64
# favorite_count                  int64
# entities                       object
# tweet_source                   object
# user_screenname                object
# user_name                      object
# location                       object
# user_description               object
# user_followers                  int64
# user_friends                    int64
# user_create_account    datetime64[ns]
# tweet_date             datetime64[ns]
# tweet_time                     object
# dtype: object

# %%
dataframe['tweet_date']=dataframe['tweet_date'].astype('datetime64[ns]')
dataframe['user_create_account']=dataframe['user_create_account'].astype('datetime64[ns]')

dataframe.dtypes
# Out:
# Unnamed: 0                      int64
# Datetime               datetime64[ns]
# Tweet Id                        int64
# Text                           object
# retweet_count                   int64
# favorite_count                  int64
# entities                       object
# tweet_source                   object
# user_screenname                object
# user_name                      object
# location                       object
# user_description               object
# user_followers                  int64
# user_friends                    int64
# user_create_account    datetime64[ns]
# tweet_date             datetime64[ns]
# tweet_time                     object
# dtype: object

# %%
dataframe.columns
# Out:
# Index(['Datetime', 'Tweet Id', 'Text', 'retweet_count', 'favorite_count',
#        'entities', 'tweet_source', 'user_screenname', 'user_name', 'location',
#        'user_description', 'user_followers', 'user_friends',
#        'user_create_account', 'tweet_date', 'tweet_time'],
#       dtype='object')

# %%
dataframe
# Out:
#                  Datetime             Tweet Id  \
# 0     2020-02-06 09:29:10  1225350710935638016
# 1     2020-02-05 09:37:26  1224990403780280320
# 2     2020-02-05 09:27:28  1224987896668721152
# 3     2020-02-05 09:08:08  1224983029799694339
# 4     2020-02-05 09:06:08  1224982527112351745
# ...                   ...                  ...
# 21042 2018-11-06 09:52:41  1059745377551872000
# 21043 2018-11-03 14:13:58  1058723965068283905
# 21044 2018-10-25 16:50:10  1055501786277134337
# 21045 2018-10-21 10:24:03  1053955064727953408
# 21046 2018-10-19 14:35:25  1053293548731158528
#
#                                                     Text  retweet_count  \
# 0                                  @samousavia میلی‌لیتر              0
# 1      RT @Majid6359: #سناتور_مکنزی وزیر کشاورزی و وز...              3
# 2      @omidhosseini80 ما گول نمی‌خوریم. یه عمریه هر ...              0
# 3      @omidhosseini80 یه آخوند بی‌عمامه دیدم. داشتم ...              0
# ...

# %%
# dataframe.to_csv('political_tweets_v2.csv', header=True,encoding='utf-8')

df= pd.read_csv('political_tweets_v2.csv', )

# %%
df
# Out:
#        Unnamed: 0             Datetime             Tweet Id  \
# 0               0  2020-02-06 09:29:10  1225350710935638016
# 1               1  2020-02-05 09:37:26  1224990403780280320
# 2               2  2020-02-05 09:27:28  1224987896668721152
# 3               3  2020-02-05 09:08:08  1224983029799694339
# 4               4  2020-02-05 09:06:08  1224982527112351745
# ...           ...                  ...                  ...
# 21042       21042  2018-11-06 09:52:41  1059745377551872000
# 21043       21043  2018-11-03 14:13:58  1058723965068283905
# 21044       21044  2018-10-25 16:50:10  1055501786277134337
# 21045       21045  2018-10-21 10:24:03  1053955064727953408
# 21046       21046  2018-10-19 14:35:25  1053293548731158528
#
#                                                     Text  retweet_count  \
# 0                                  @samousavia میلی‌لیتر              0
# 1      RT @Majid6359: #سناتور_مکنزی وزیر کشاورزی و وز...              3
# ...

# %%
del df['Unnamed: 0']

# %%
df.dtypes
# Out:
# Datetime               object
# Tweet Id                int64
# Text                   object
# retweet_count           int64
# favorite_count          int64
# entities               object
# tweet_source           object
# user_screenname        object
# user_name              object
# location               object
# user_description       object
# user_followers          int64
# user_friends            int64
# user_create_account    object
# tweet_date             object
# tweet_time             object
# dtype: object

# %%
dataframe['tweet_date']=dataframe['tweet_date'].astype('datetime64[ns]')
dataframe['user_create_account']=dataframe['user_create_account'].astype('datetime64[ns]')

dataframe.dtypes
# Out:
# Datetime               datetime64[ns]
# Tweet Id                        int64
# Text                           object
# retweet_count                   int64
# favorite_count                  int64
# entities                       object
# tweet_source                   object
# user_screenname                object
# user_name                      object
# location                       object
# user_description               object
# user_followers                  int64
# user_friends                    int64
# user_create_account    datetime64[ns]
# tweet_date             datetime64[ns]
# tweet_time                     object
# dtype: object

# %%
df.describe(include = "all")
# Out:
#                    Datetime      Tweet Id  \
# count                 21047  2.104700e+04
# unique                20713           NaN
# top     2020-01-20 06:05:07           NaN
# freq                      4           NaN
# mean                    NaN  1.087622e+18
# std                     NaN  1.294495e+17
# min                     NaN  2.842295e+17
# 25%                     NaN  1.027833e+18
# 50%                     NaN  1.117935e+18
# 75%                     NaN  1.192533e+18
# max                     NaN  1.226423e+18
#
#                                                     Text  retweet_count  \
# count                                              21047   21047.000000
# unique                                             20838            NaN
# top     @hesamodllin1 حساب کاربری@hesamodllin1 جعلی است.            NaN
# freq                                                  14            NaN
# mean                                                 NaN     102.369364
# ...

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    Datetime  Tweet Id   Text  retweet_count  favorite_count  entities  \
# 0     False     False  False          False           False     False
# 1     False     False  False          False           False     False
# 2     False     False  False          False           False     False
# 3     False     False  False          False           False     False
# 4     False     False  False          False           False     False
#
#    tweet_source  user_screenname  user_name  location  user_description  \
# 0         False            False      False      True              True
# 1         False            False      False      True              True
# 2         False            False      False      True              True
# 3         False            False      False      True              True
# 4         False            False      False      True              True
#
#    user_followers  user_friends  user_create_account  tweet_date  tweet_time
# ...

# %%
for column in missing_data.columns.values.tolist():
    print("\n")
    print(column)
    print(missing_data[column].value_counts())
# Out:
# Datetime
# False    21047
# Name: Datetime, dtype: int64
#
#
# Tweet Id
# False    21047
# Name: Tweet Id, dtype: int64
#
#
# Text
# False    21047
# Name: Text, dtype: int64
#
#
# retweet_count
# False    21047
# Name: retweet_count, dtype: int64
#
#
# favorite_count
# False    21047
# Name: favorite_count, dtype: int64
#
#
# entities
# False    21047
# Name: entities, dtype: int64
#
#
# tweet_source
# False    21047
# Name: tweet_source, dtype: int64
#
#
# user_screenname
# False    21047
# Name: user_screenname, dtype: int64
#
#
# user_name
# False    21047
# Name: user_name, dtype: int64
#
#
# location
# False    17170
# True      3877
# Name: location, dtype: int64
#
#
# user_description
# False    20138
# True       909
# Name: user_description, dtype: int64
#
#
# user_followers
# False    21047
# Name: user_followers, dtype: int64
#
#
# user_friends
# False    21047
# Name: user_friends, dtype: int64
#
#
# user_create_account
# False    21047
# ...

# %%
df['user_screenname'].value_counts()
# Out:
# Alirabiei_ir      200
# DrSaeedJalili     200
# S_A_Salehi        200
# HasankarimiG      200
# mah_sadeghi       200
#                  ...
# HassanNooroozi     12
# BijanZanganeh       4
# rezarahmanii        3
# MMirlohii           1
# yagob_shivyari      1
# Name: user_screenname, Length: 143, dtype: int64

# %%
df['user_screenname'].unique()
# Out:
# array(['1alpr', 'AfshinHabibzade', 'ahadazadikhah', 'ahmadamirabadi1',
#        'ahmadhematii', 'Ahmadinejad1956', 'Ahmadinejad_fa',
#        'Ahmadkhatami_ir', 'AK_Hosseinzadeh', 'alia_peyvandi',
#        'AliEtaMedia', 'alimotahari_ir', 'AliNajafi_ir', 'Alirabiei_ir',
#        'alirezaghanadan', 'AliSari1397', 'alishakourirad', 'AMasjedjamei',
#        'aminimedia_ir', 'amirnazemy', 'araghchi', 'ArvinBahare',
#        'ar_moezi', 'AshrafBrujerdi', 'azarijahromi', 'Azizjafaari_ir',
#        'a_rahimi_mp', 'A_Yarmohammadi', 'Badamchi_Media', 'baeidinejad',
#        'barari_ir', 'BijanZanganeh', 'Dastjerdi_ir', 'DrAboutalebi',
#        'Drjalilrahimi', 'drmdehghan', 'DrSaeedJalili', 'Dr_Vaezi',
#        'ebtekarm_ir', 'ElhamFakhari', 'elyashazrati', 'Eshaq_jahangiri',
#        'EsmaeiliParviz', 'farahani52', 'Fassih_F', 'fatahi_ir',
#        'fazelmaybodi', 'ghasemsoleimane', 'Ghheidari', 'HaddadAdel_ir',
#        'HadiKhaniki', 'HajiDeligani', 'hajmajid47', 'HaniyehSamei',
# ...

# %%
print('number of account: ' , len(df['user_screenname'].unique()))
# Out:
# number of account:  143

# %%
df['tweet_date']=df['tweet_date'].astype('datetime64[ns]')
monthly_df = df.groupby([df['tweet_date'].dt.year.rename('year'), df['tweet_date'].dt.month.rename('month')]).agg({'count'})
# monthly_df.hist()

monthly_df
# Out:
#            Datetime Tweet Id  Text retweet_count favorite_count entities  \
#               count    count count         count          count    count
# year month
# 2012 12           6        6     6             6              6        6
# 2013 1           21       21    21            21             21       21
#      2            5        5     5             5              5        5
#      11           7        7     7             7              7        7
#      12           6        6     6             6              6        6
# ...             ...      ...   ...           ...            ...      ...
# 2019 10         969      969   969           969            969      969
#      11        1047     1047  1047          1047           1047     1047
#      12        1297     1297  1297          1297           1297     1297
# 2020 1         2600     2600  2600          2600           2600     2600
#      2          603      603   603           603            603      603
#
# ...
