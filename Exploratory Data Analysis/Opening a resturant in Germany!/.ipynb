# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !pip install geopy 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !pip install folium
import folium # plotting library

print('Libraries imported.')
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl
# ...
# Libraries imported.

# %%
# Define Foursquare Credentials and Version

CLIENT_ID = 'H3G0MS03VMAAZT0JO0JDJAXMRIKF1JQZKPOFGVVVCP22GYBV' # your Foursquare ID
CLIENT_SECRET = '5LVZ5MOFO4SN0OQKN3F4IFHQTVHEGXLVGDPB4WXKNQTXWRML' # your Foursquare Secret
VERSION = '20202101'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: H3G0MS03VMAAZT0JO0JDJAXMRIKF1JQZKPOFGVVVCP22GYBV
# CLIENT_SECRET:5LVZ5MOFO4SN0OQKN3F4IFHQTVHEGXLVGDPB4WXKNQTXWRML

# %%
# address = '102 North End Ave, New York, NY'
address = "Essen, North Rhine-Westphalia"

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.4582235 7.0158171

# %%
# Search for a specific venue category
search_query = 'Café'
radius = 5000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

print(search_query + ' .... OK!')
# Out:
# Café .... OK!

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e60cf1be826ac00205ea387'},
#  'response': {'venues': [{'id': '4ba54152f964a52059f238e3',
#     'name': 'Cafe Nord',
#     'location': {'address': 'Viehofer Platz 1',
#      'lat': 51.46185586552524,
#      'lng': 7.0137366494571545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.46185586552524,
#        'lng': 7.0137366494571545}],
#      'distance': 429,
#      'postalCode': '45127',
#      'cc': 'DE',
#      'city': 'Essen',
#      'state': 'Nordrhein-Westfalen',
#      'country': 'Deutschland',
#      'formattedAddress': ['Viehofer Platz 1', '45127 Essen', 'Deutschland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583402916',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
# print(venues)
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
#                           id                                      name  \
# 0   4ba54152f964a52059f238e3                                 Cafe Nord
# 1   4c49760c9f2ad13a53f24f53                  ÇAGDAŞ Café - Restaurant
# 2   4ca7488a97c8a1cda48478a5                               Cáfe Kötter
# 3   4fb5e09fe4b0b85e6efc8755                         Mona's Café-Treff
# 4   4d53d15abdbea1cd7ad1df92      HeartRock Cafe Elisabeth Krankenhaus
# 5   4da7327c1e725f12297deaab                         Cafe & Bar Celona
# 6   4ba578acf964a520820a39e3                           Cafe Extrablatt
# 7   5c79a33125fb7b002c0067f7                           Café Extrablatt
# 8   5749d8af498e4e488345e8db                    WonderCrepe Diner Café
# 9   4c48407796abd13ab8987301                               Café Giallo
# 10  5a21dda8ee712062bfa927ee                          Louis Café & Bar
# 11  4cebf484678aa0930963fbea                                Café Rosso
# ...

# %%
dataframe.shape
# Out:
# (50, 19)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                         name          categories  \
# 0                                  Cafe Nord                 Pub
# 1                   ÇAGDAŞ Café - Restaurant  Turkish Restaurant
# 2                                Cáfe Kötter                Café
# 3                          Mona's Café-Treff                Café
# 4       HeartRock Cafe Elisabeth Krankenhaus          Restaurant
# 5                          Cafe & Bar Celona                Café
# 6                            Cafe Extrablatt                Café
# 7                            Café Extrablatt                Café
# 8                     WonderCrepe Diner Café            Creperie
# 9                                Café Giallo   College Cafeteria
# 10                          Louis Café & Bar                 Bar
# 11                                Café Rosso         Coffee Shop
# 12                                  cafe iks                Café
# ...

# %%
dataframe_filtered.name.to_frame()
# Out:
#                                         name
# 0                                  Cafe Nord
# 1                   ÇAGDAŞ Café - Restaurant
# 2                                Cáfe Kötter
# 3                          Mona's Café-Treff
# 4       HeartRock Cafe Elisabeth Krankenhaus
# 5                          Cafe & Bar Celona
# 6                            Cafe Extrablatt
# 7                            Café Extrablatt
# 8                     WonderCrepe Diner Café
# 9                                Café Giallo
# 10                          Louis Café & Bar
# 11                                Café Rosso
# 12                                  cafe iks
# 13                   DINEA Café & Restaurant
# 14                              Cafe Klatsch
# 15                            Café Solo Loft
# 16                             Cafe Metropol
# 17                         Prince Café & Bar
# 18                          Cafe & Bar Mondo
# 19  abia Bistrorant - Cocktail Lounge - Cafe
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Shiraz Central

# add a red circle marker to represent the Shiraz Center
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Essen',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the cafe blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Explore Cafe Ferdowsi ID= 51811167498e27297dd8c3d8


venue_id = '51811167498e27297dd8c3d8' # ID of Ferdowsi Cafe
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/51811167498e27297dd8c3d8?client_id=H3G0MS03VMAAZT0JO0JDJAXMRIKF1JQZKPOFGVVVCP22GYBV&client_secret=5LVZ5MOFO4SN0OQKN3F4IFHQTVHEGXLVGDPB4WXKNQTXWRML&v=20202101'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '51811167498e27297dd8c3d8',
#  'name': 'Ferdowsi Café | کافه فردوسی (کافه فردوسی)',
#  'contact': {'phone': '+987132316616', 'formattedPhone': '+98 71 3231 6616'},
#  'location': {'address': 'Ferdowsi St.',
#   'lat': 29.624204901392527,
#   'lng': 52.540144761915045,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 29.624204901392527,
#     'lng': 52.540144761915045}],
#   'postalCode': '194',
#   'cc': 'IR',
#   'city': 'شیراز',
#   'state': 'فارس',
#   'country': 'ایران',
#   'formattedAddress': ['Ferdowsi St.', 'شیراز, فارس 194', 'ایران']},
# ...

# %%
#  Get the venue's overall rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
    
print("Number of tipes: ", result['response']['venue']['tips']['count'])
# Out:
# 8.5
# Number of tipes:  122

# %%
# Delfico Café Gelateria ID = 58fcb8d950a6f05953f6efe2

venue_id = '58fcb8d950a6f05953f6efe2' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.7

# %%
print("Number of tipes: ", result['response']['venue']['tips']['count'])
# Out:
# Number of tipes:  18

# %%
venue_id = '51811167498e27297dd8c3d8' # ID of Ferdowsi Cafe

limit = 123 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e2737673907e70022b3c880'},
#  'response': {'tips': {'count': 123,
#    'items': [{'id': '541d0a6711d2e8f496a1f28c',
#      'createdAt': 1411189351,
#      'text': 'Friendly nice cafe close to Shiraz center. Enjoyed the drinks and the salat a lot. The staff is friendly and helpful, the crowd seems also open and interested. Great place to hang out for an afternoon',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/541d0a6711d2e8f496a1f28c',
#      'lang': 'en',
#      'likes': {'count': 8,
#       'groups': [{'type': 'others',
#         'count': 8,
#         'items': [{'id': '47878164',
#           'firstName': 'Parisa',
#           'lastName': 'H',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/47878164-HVWKUIUMXIEDGOCB.jpg'}},
#          {'id': '93514689',
#           'firstName': 'Ali',
#           'lastName': 'B',
# ...

# %%
# Get tips and list of associated features
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
# Format column width and display all tips

pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# C:\Users\behdad\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                                                                                                        text  \
# 0  Friendly nice cafe close to Shiraz center. Enjoyed the drinks and the salat a lot. The staff is friendly and helpful, the crowd seems also open and interested. Great place to hang out for an afternoon
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  14          0              541d0a6711d2e8f496a1f28c  Alexander
#
#   user.lastName  user.gender   user.id
# ...

# %%
latitude = 29.624204901392527
longitude =  52.540144761915045
radius = 2000
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=H3G0MS03VMAAZT0JO0JDJAXMRIKF1JQZKPOFGVVVCP22GYBV&client_secret=5LVZ5MOFO4SN0OQKN3F4IFHQTVHEGXLVGDPB4WXKNQTXWRML&ll=29.624204901392527,52.540144761915045&v=20202101&radius=2000&limit=100'

# %%
results = requests.get(url).json()
'There are {} around Ferdowsi cafe.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 around Ferdowsi cafe.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '51811167498e27297dd8c3d8',
#   'name': 'Ferdowsi Café | کافه فردوسی (کافه فردوسی)',
#   'location': {'address': 'Ferdowsi St.',
#    'lat': 29.624204901392527,
#    'lng': 52.540144761915045,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 29.624204901392527,
#      'lng': 52.540144761915045}],
#    'distance': 0,
#    'postalCode': '194',
#    'cc': 'IR',
#    'city': 'شیراز',
#    'state': 'فارس',
#    'country': 'ایران',
#    'formattedAddress': ['Ferdowsi St.', 'شیراز, فارس 194', 'ایران']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
# ...

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                                   name          categories  \
# 0  Ferdowsi Café | کافه فردوسی (کافه فردوسی)            Café
# 1  Karimkhan Hotel | هتل کریمخان                        Hotel
# 2  Zandieh Hotel | هتل زندیه                            Hotel
# 3  Naqashi Café | کافه نقّاشی (کافه نقّاشی)             Café
# 4  Homa Hotel | هتل هما (هتل هما)                       Hotel
# 5  بوکلند                                               Bookstore
# 6  The Arg of Karim Khan | ارگ کریم خان (ارگ کریم خان)  Castle
# 7  Shapouri Residence | عمارت شاپوری (عمارت شاپوری)     Historic Site
# 8  Enghelab Bazaar | بازار انقلاب (بازار انقلاب)        Market
# 9  Roodaki Restaurant | رستوران رودکی (رستوران رودکی)   Persian Restaurant
#
#                 address  cc    city country           crossStreet  distance  \
# 0  Ferdowsi St.          IR  شیراز   ایران   NaN                   0
# 1  Roodaki St.           IR  Shiraz  ایران   NaN                   262
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Cafe Ferdowsi


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Cafe Ferdowsi',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e2739cb6001fe001ba7bc22'},
#  'response': {'venues': [{'id': '5a41738718d43b4d3288b190',
#     'name': 'Joulep Café | کافه ژولپ (کافه ژولپ)',
#     'location': {'address': 'Taleqani St.',
#      'crossStreet': 'Farhang',
#      'lat': 29.6149688437492,
#      'lng': 52.54565332937331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.6149688437492,
#        'lng': 52.54565332937331}],
#      'distance': 1158,
#      'postalCode': '7137754366',
#      'cc': 'IR',
#      'neighborhood': 'Vakil Bath/Mosque',
#      'city': 'شیراز',
#      'state': 'فارس',
#      'country': 'ایران',
#      'formattedAddress': ['Taleqani St. (Farhang)',
#       'شیراز, فارس 7137754366',
#       'ایران']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
# ...

# %%
# Check if any venues are trending at this time
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
#                                   name categories  location.distance  \
# 0  Joulep Café | کافه ژولپ (کافه ژولپ)  Café       1158
#
#   location.city location.postalCode location.state location.country  \
# 0  شیراز         7137754366          فارس           ایران
#
#    location.lat  location.lng
# 0  29.614969     52.545653

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
